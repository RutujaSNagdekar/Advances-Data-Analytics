# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('titanic-tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
#Drop row with missing values
#df = df.dropna()
df
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Define features antarget variables
features = ['Pclass', 'Gender', 'Age', 'SibSp', 'Embarked']
target = 'Survived'

# %%
#Encode categorical
encoder = LabelEncoder()
for col in features:
    if df[col].dtype == object:
        df[col] = encoder.fit_transform(df[col])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James       1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)       0  47.0      1      0
# 2                       Myles, Mr. Thomas Francis       1  62.0      0      0
# 3                                Wirz, Mr. Albert       1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)       0  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf       1   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina       0  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen       1  38.5      0      0
# 416                           Ware, Mr. Frederick       1   NaN      0      0
# 417                      Peter, Master. Michael J       1   NaN      1      1
#
#                  Ticket      Fare Cabin  Embarked
# 0                330911    7.8292   NaN         1
# 1                363272    7.0000   NaN         2
# 2                240276    9.6875   NaN         1
# 3                315154    8.6625   NaN         2
# 4               3101298   12.2875   NaN         2
# ..                  ...       ...   ...       ...
# 413           A.5. 3236    8.0500   NaN         2
# 414            PC 17758  108.9000  C105         0
# 415  SOTON/O.Q. 3101262    7.2500   NaN         2
# 416              359309    8.0500   NaN         2
# 417                2668   22.3583   NaN         0
#
# [418 rows x 12 columns]

# %%
#SCale numeric features (Age)
scaler = StandardScaler()
df['Age'] = scaler.fit_transform(df[['Age']])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Gender       Age  SibSp  \
# 0                                Kelly, Mr. James       1  0.298549      0
# 1                Wilkes, Mrs. James (Ellen Needs)       0  1.181328      1
# 2                       Myles, Mr. Thomas Francis       1  2.240662      0
# 3                                Wirz, Mr. Albert       1 -0.231118      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)       0 -0.584229      1
# ..                                            ...     ...       ...    ...
# 413                            Spector, Mr. Woolf       1       NaN      0
# 414                  Oliva y Ocana, Dona. Fermina       0  0.616350      0
# 415                  Saether, Mr. Simon Sivertsen       1  0.581038      0
# 416                           Ware, Mr. Frederick       1       NaN      0
# 417                      Peter, Master. Michael J       1       NaN      1
#
#      Parch              Ticket      Fare Cabin  Embarked
# 0        0              330911    7.8292   NaN         1
# 1        0              363272    7.0000   NaN         2
# 2        0              240276    9.6875   NaN         1
# 3        0              315154    8.6625   NaN         2
# 4        1             3101298   12.2875   NaN         2
# ..     ...                 ...       ...   ...       ...
# 413      0           A.5. 3236    8.0500   NaN         2
# 414      0            PC 17758  108.9000  C105         0
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN         2
# 416      0              359309    8.0500   NaN         2
# 417      1                2668   22.3583   NaN         0
#
# [418 rows x 12 columns]

# %%
#Separate features and target 
X = df[features]
y = df[target]

# %%
X_train,X_test, Y_train, Y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
#Create decision tree cklassifier
model = DecisionTreeClassifier()
model = model.fit(X_train , Y_train)
model
# Out:
# DecisionTreeClassifier()

# %%
y_pred  = model.predict(X_test)

# %%
from sklearn.metrics  import confusion_matrix
from sklearn import metrics

# %%
#Print various classification metrics
print('Confusion Matrix : ', confusion_matrix(Y_test, y_pred))
print('Accuracy: ', metrics.accuracy_score(Y_test, y_pred))
print('Precision Score: ', metrics.precision_score(Y_test, y_pred))
print('Recall  Score: ', metrics.recall_score(Y_test, y_pred))
print('F1 Score: ', metrics.f1_score(Y_test, y_pred))
print('Classification Report: ', metrics.classification_report(Y_test, y_pred))
# Out:
# Confusion Matrix :  [[58  0]
#  [ 0 26]]
# Accuracy:  1.0
# Precision Score:  1.0
# Recall  Score:  1.0
# F1 Score:  1.0
# Classification Report:                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        58
#            1       1.00      1.00      1.00        26
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84

# %%
#Print importance of each feature
print('Feature Importance')
for feature, importance in zip(features, model.feature_importances_):
    print(f'{feature} :{importance :.2f} ')
# Out:
# Feature Importance
# Pclass :0.00
# Gender :1.00
# Age :0.00
# SibSp :0.00
# Embarked :0.00

# %%
#Save the tree as image 
#Three options
#OPtion 1 - Create dot file and then convert manually to png format
#Save the tree as DOT file 
with open('titanic_tree.dot' , 'w') as f:
    export_graphviz(model , out_file = f, feature_names=features, filled = True)
#You have to say dot -Tpng titanic_tree.dot -o titanic_tree.png to convert

# %%
#Option 2
#Convert directly on png
from io import StringIO
from IPython.display import Image
import pydotplus

# %%
dot_df = StringIO()
dot_df

# %%
export_graphviz(model , out_file= dot_df , filled = True , rounded = True , special_characters=True, feature_names=features, class_names= ['0', '1'])
graph = pydotplus.graph_from_dot_data(dot_df.getvalue())

# %%
graph.write_png('titanic.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 graph.write_png('titanic.png')
#       2 Image(graph.create_png())
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1810, in Dot.__init__.<locals>.<lambda>(path, f, prog)
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#    1805 for frmt in self.formats + ['raw']:
#    1806     self.__setattr__(
#    1807         'write_' + frmt,
#    1808         lambda path,
#    1809         f=frmt,
# -> 1810         prog=self.prog: self.write(path, format=f, prog=prog)
#    1811     )
#    1813     f = self.__dict__['write_' + frmt]
#    1814     f.__doc__ = (
#    1815         '''Refer to the docstring accompanying the'''
#    1816         ''''write' method for more information.'''
#    1817     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1918, in Dot.write(self, path, prog, format)
#    1915         fobj.write(data)
#    1917     else:
# -> 1918         fobj.write(self.create(prog, format))
#    1919 finally:
#    1920     if close:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found

# %%
#OPtion 3
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    -------------------------- ------------- 30.7/47.1 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 47.1/47.1 kB 784.8 kB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3

# %%
import graphviz

# %%
dot_df =
