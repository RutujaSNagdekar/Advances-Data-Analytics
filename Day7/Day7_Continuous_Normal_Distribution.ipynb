# %%
#Continuous probability Distribution
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
df = pd.read_csv('hs_heights_pair.csv')
df
# Out:
#       boys  girls
# 0    64.44  62.47
# 1    67.40  63.27
# 2    63.93  62.99
# 3    69.29  64.60
# 4    66.96  60.73
# ..     ...    ...
# 495  70.89  65.69
# 496  62.13  58.06
# 497  72.97  62.42
# 498  67.23  62.18
# 499  71.85  58.54
#
# [500 rows x 2 columns]

# %%
boys_heights = df['boys']
girls_heights = df['girls']

# %%
mean_boys = np.mean(boys_heights)
std_boys= np.std(boys_heights)

# %%
mean_girls = np.mean(girls_heights)
std_girls= np.std(girls_heights)

# %%
print(f"Boys ----Mean: {mean_boys}, Standard Deviation: {std_boys}")
print(f"Girls---Mean: {mean_girls}, Standard Deviation: {std_girls}")
# Out:
# Boys ----Mean: 67.16386, Standard Deviation: 2.887270839460683
# Girls---Mean: 61.9776, Standard Deviation: 2.1157724452312916

# %%
#Define colors for SD lines
colors = ['green', 'orange', 'red']

# %%
plt.figure(figsize=(14,6))

#Plot for boys
plt.subplot(1,2,1)
sns.histplot(boys_heights, kde = True, stat= 'density', linewidth=0)
xmin, xmax = plt.xlim()

x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean_boys, std_boys)
plt.plot(x,p,'k', linewidth=2)
title = "Boys Heights\nMean= {:.2f} , SD = {:.2f} ".format(mean_boys, std_boys)
plt.title(title)

#PLot standard deviation lines for boys

for i in range(1,4):
    plt.axvline(mean_boys + i *std_boys, color = colors[i-1], linestyle='--')
    plt.axvline(mean_boys - i *std_boys, color = colors[i-1], linestyle='--')



#Plot for girls
plt.subplot(1,2,2)
sns.histplot(girls_heights, kde = True, stat= 'density', linewidth=0)
xmin, xmax = plt.xlim()

x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean_girls, std_girls)
plt.plot(x,p,'k', linewidth=2)
title = "Girls Heights\nMean= {:.2f} , SD = {:.2f} ".format(mean_girls, std_girls)
plt.title(title)

#PLot standard deviation lines for boys

for i in range(1,4):
    plt.axvline(mean_girls + i *std_girls, color = colors[i-1], linestyle='--')
    plt.axvline(mean_girls - i *std_girls, color = colors[i-1], linestyle='--')

# %%
plt.figure(figsize=(14,6))

#Plot for boys
plt.subplot(1,2,1)
sns.histplot(boys_heights, kde = True, stat= 'density', linewidth=0)
min, xmax = plt.xlim()
print(xmin, xmax )
# Out:
# 58.26049999999999 78.04950000000001

# %%
#Question Practice
#Draw normal distribution plot for the completion time column of the marathon datasets . separately for the male and female athletes. 
#Also show the mean +/- 1,2,3 lines.

# %%
df_2015 = pd.read_csv('marathon_results_2015.csv')
df_2016 = pd.read_csv('marathon_results_2016.csv')
df_2017 = pd.read_csv('marathon_results_2017.csv')

# %%
df = pd.concat([df_2015,df_2016,df_2017])

# %%
df
# Out:
#        Unnamed: 0    Bib                      Name  Age M/F          City  \
# 0             0.0      3            Desisa, Lelisa   25   M          Ambo
# 1             1.0      4     Tsegay, Yemane Adhane   30   M   Addis Ababa
# 2             2.0      8            Chebet, Wilson   29   M      Marakwet
# 3             3.0     11          Kipyego, Bernard   28   M       Eldoret
# 4             4.0     10             Korir, Wesley   32   M        Kitale
# ...           ...    ...                       ...  ...  ..           ...
# 26405     26405.0  25166  Steinbach, Paula Eyvonne   61   F       Ontario
# 26406     26406.0  25178        Avelino, Andrew R.   25   M  Fayetteville
# 26407     26407.0  27086           Hantel, Johanna   57   F       Malvern
# 26408     26408.0  25268              Reilly, Bill   64   M      New York
# 26409     26409.0  25266             Rigsby, Scott   48   M    Alpharetta
#
#       State Country Citizen Unnamed: 9  ...      30K      35K      40K  \
# ...

# %%
df[['hour','mins','seconds']] = df['Official Time'].str.split(':', expand = True)

# %%
df['hour'] = df['hour'].astype(int)
df['mins'] = df['mins'].astype(int)
df['seconds'] = df['seconds'].astype(int)

# %%
df['total_time'] = df['hour']*3600+df['mins']*60+df['seconds']

# %%
df
# Out:
#        Unnamed: 0    Bib                      Name  Age M/F          City  \
# 0             0.0      3            Desisa, Lelisa   25   M          Ambo
# 1             1.0      4     Tsegay, Yemane Adhane   30   M   Addis Ababa
# 2             2.0      8            Chebet, Wilson   29   M      Marakwet
# 3             3.0     11          Kipyego, Bernard   28   M       Eldoret
# 4             4.0     10             Korir, Wesley   32   M        Kitale
# ...           ...    ...                       ...  ...  ..           ...
# 26405     26405.0  25166  Steinbach, Paula Eyvonne   61   F       Ontario
# 26406     26406.0  25178        Avelino, Andrew R.   25   M  Fayetteville
# 26407     26407.0  27086           Hantel, Johanna   57   F       Malvern
# 26408     26408.0  25268              Reilly, Bill   64   M      New York
# 26409     26409.0  25266             Rigsby, Scott   48   M    Alpharetta
#
#       State Country Citizen Unnamed: 9  ... Proj Time Official Time Overall  \
# ...

# %%
male = df[df['M/F']=='M']
female = df[df['M/F']=='F']

# %%
male
# Out:
#        Unnamed: 0    Bib                   Name  Age M/F          City State  \
# 0             0.0      3         Desisa, Lelisa   25   M          Ambo   NaN
# 1             1.0      4  Tsegay, Yemane Adhane   30   M   Addis Ababa   NaN
# 2             2.0      8         Chebet, Wilson   29   M      Marakwet   NaN
# 3             3.0     11       Kipyego, Bernard   28   M       Eldoret   NaN
# 4             4.0     10          Korir, Wesley   32   M        Kitale   NaN
# ...           ...    ...                    ...  ...  ..           ...   ...
# 26403     26403.0  31283       Leroy, Stefan M.   25   M       Jupiter    FL
# 26404     26404.0  25141         Quinn, Adam H.   19   M       Belmont    MI
# 26406     26406.0  25178     Avelino, Andrew R.   25   M  Fayetteville    NC
# 26408     26408.0  25268           Reilly, Bill   64   M      New York    NY
# 26409     26409.0  25266          Rigsby, Scott   48   M    Alpharetta    GA
#
# ...

# %%
male_mean = male['total_time'].mean()
male_mean
male_std = male['total_time'].std()
male_std
# Out:
# 2518.2444966945586

# %%
female_mean = female['total_time'].mean()
female_std = female['total_time'].std()

# %%
print(f"Male ----Mean: {male_mean}, Standard Deviation: {male_std}")
print(f"Female---Mean: {female_mean}, Standard Deviation: {female_std}")
# Out:
# Male ----Mean: 13426.911664596844, Standard Deviation: 2518.2444966945586
# Female---Mean: 14667.026385662131, Standard Deviation: 2283.721992053481

# %%
#Define colors for SD lines
colors = ['green', 'orange', 'red']

# %%
plt.figure(figsize=(14,6))

#Plot for males
plt.subplot(1,2,1)
sns.histplot(male['total_time'], kde = True, stat= 'density', linewidth=0)
xmin, xmax = plt.xlim()

x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x,male_mean ,male_std )
plt.plot(x,p,'k', linewidth=2)
title = "Male time\nMean= {:.2f}seconds , SD = {:.2f} ".format(male_mean,male_std )
plt.title(title)

#PLot standard deviation lines for boys

for i in range(1,4):
    plt.axvline(male_mean + i *male_std, color = colors[i-1], linestyle='--')
    plt.axvline(male_mean - i *male_std, color = colors[i-1], linestyle='--')



#Plot for Females
plt.subplot(1,2,2)
sns.histplot(female['total_time'], kde = True, stat= 'density', linewidth=0)
xmin, xmax = plt.xlim()

x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, female_mean, female_std)
plt.plot(x,p,'k', linewidth=2)
title = "Girls Heights\nMean= {:.2f}seconds, SD = {:.2f} ".format(female_mean, female_std)
plt.title(title)

#PLot standard deviation lines for boys

for i in range(1,4):
    plt.axvline(female_mean + i *female_std, color = colors[i-1], linestyle='--')
    plt.axvline(female_mean - i *female_std, color = colors[i-1], linestyle='--')
