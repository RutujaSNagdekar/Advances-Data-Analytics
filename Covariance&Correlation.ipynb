# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('weight-height.csv')
print(df.head())
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
#separte data based on gender 
df_male=df[df['Gender'] == 'Male']
df_female=df[df['Gender'] == 'Female']
df_male
# Out:
#      Gender     Height      Weight
# 0      Male  73.847017  241.893563
# 1      Male  68.781904  162.310473
# 2      Male  74.110105  212.740856
# 3      Male  71.730978  220.042470
# 4      Male  69.881796  206.349801
# ...     ...        ...         ...
# 4995   Male  68.860062  177.131052
# 4996   Male  68.973423  159.285228
# 4997   Male  67.013795  199.195400
# 4998   Male  71.557718  185.905909
# 4999   Male  70.351880  198.903012
#
# [5000 rows x 3 columns]

# %%
#Calculate corelation
corr_overall=df[['Height','Weight']].corr()
corr_male=df_male[['Height','Weight']].corr()
corr_female=df_female[['Height','Weight']].corr()

print(corr_overall)
print(corr_male)
print(corr_female)
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000
#           Height    Weight
# Height  1.000000  0.862979
# Weight  0.862979  1.000000
#           Height    Weight
# Height  1.000000  0.849609
# Weight  0.849609  1.000000

# %%
corr_overall
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
corr_male
# Out:
#           Height    Weight
# Height  1.000000  0.862979
# Weight  0.862979  1.000000

# %%
corr_female
# Out:
#           Height    Weight
# Height  1.000000  0.849609
# Weight  0.849609  1.000000

# %%
#Calculate covariance
cov_overall=df[['Height','Weight']].cov()
cov_male=df_male[['Height','Weight']].cov()
cov_female=df_female[['Height','Weight']].cov()

# %%
print("Overall corelation between height and weight:")
print(corr_overall)
# Out:
# Overall corelation between height and weight:
#             Height       Weight
# Height   14.803473   114.242656
# Weight  114.242656  1030.951855

# %%
print("\nMale corelation between height and weight:")
print(corr_male)
# Out:
# Male corelation between height and weight:
#            Height      Weight
# Height   8.198843   48.879649
# Weight  48.879649  391.294074

# %%
print("\nFemale corelation between height and weight:")
print(corr_female)
# Out:
# Female corelation between height and weight:
#            Height      Weight
# Height   7.269947   43.576404
# Weight  43.576404  361.854281

# %%
print("Overall covariance between height and weight:")
print(cov_overall)
# Out:
# Overall covariance between height and weight:
#             Height       Weight
# Height   14.803473   114.242656
# Weight  114.242656  1030.951855

# %%
print("\nFemale covariance between height and weight:")
print(cov_female)
# Out:
# Female covariance between height and weight:
#            Height      Weight
# Height   7.269947   43.576404
# Weight  43.576404  361.854281

# %%
print("\nMale covariance between height and weight:")
print(cov_male)
# Out:
# Male covariance between height and weight:
#            Height      Weight
# Height   8.198843   48.879649
# Weight  48.879649  391.294074

# %%
#create scatter plots with corelation values
fig,axes=plt.subplots(1,3,figsize=(18,6))
#overall data plot
axes[0].scatter(df['Height'],df['Weight'],color='skyblue',alpha=0.5)
axes[0].set_title(f'Overall Correlation:{corr_overall.loc['Height','Weight']:.2f}')
axes[0].set_xlabel('Height')
axes[0].set_ylabel('Weight')
axes[0].grid(True)

#Male data plot
axes[1].scatter(df['Height'],df['Weight'],color='green',alpha=0.5)
axes[1].set_title(f'Male Correlation:{corr_male.loc['Height','Weight']:.2f}')
axes[1].set_xlabel('Height')
axes[1].set_ylabel('Weight')
axes[1].grid(True)

#female data plot
axes[2].scatter(df['Height'],df['Weight'],color='purple',alpha=0.5)
axes[2].set_title(f'Female Correlation:{corr_female.loc['Height','Weight']:.2f}')
axes[2].set_xlabel('Height')
axes[2].set_ylabel('Weight')
axes[2].grid(True)

# %%
#create scatter plots with covariance values
fig,axes=plt.subplots(1,3,figsize=(18,6))

#overall data plot
axes[0].scatter(df['Height'],df['Weight'],color='brown',alpha=0.5)
axes[0].set_title(f'Overall Covariance :{cov_overall.loc['Height','Weight']:.2f}')
axes[0].set_xlabel('Height')
axes[0].set_ylabel('Weight')
axes[0].grid(True)


#Male data plot
axes[1].scatter(df['Height'],df['Weight'],color='black',alpha=0.5)
axes[1].set_title(f'Male Covariance:{cov_male.loc['Height','Weight']:.2f}')
axes[1].set_xlabel('Height')
axes[1].set_ylabel('Weight')
axes[1].grid(True)

#Female data plot
axes[2].scatter(df['Height'],df['Weight'],color='purple',alpha=0.5)
axes[2].set_title(f'Female Covariance:{cov_male.loc['Height','Weight']:.2f}')
axes[2].set_xlabel('Height')
axes[2].set_ylabel('Weight')
axes[2].grid(True)

# %%
#heatmap
import seaborn as sns
plt.figure(figsize=(6,4))
sns.heatmap(corr_overall,annot=True,fmt=".2f",cmap="coolwarm")
plt.title("overall correlation heat map")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()
