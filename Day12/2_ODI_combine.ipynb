# %%
#Combine
#Men ODI team Match results - 20th century.csv
#Men ODI team Match results - 21th century.csv datasets
#Use naive bayes to find the porbability of India winnign next match against Australia when palying abroad
#Evaluate accuracy as before

# %%
import pandas as pd

# %%
df_1 = pd.read_csv('Men ODI Team Match Results - 20th Century.csv')
df_2 = pd.read_csv('Men ODI Team Match Results - 21st Century .csv')

# %%
df = pd.concat([df_1, df_2])
df.head(50)
# Out:
#    Result     Margin                  Match Home/Away       Ground  \
# 0    Lost  5 wickets    Australia v England      Away    Melbourne
# 1     Won  6 wickets    England v Australia      Home   Manchester
# 2    Lost  5 wickets    England v Australia      Home       Lord's
# 3     Won  2 wickets    England v Australia      Home   Birmingham
# 4     Won  7 wickets  England v New Zealand      Home      Swansea
# 5     N/R          -  England v New Zealand      Home   Manchester
# 6     Won  1 wickets  England v West Indies      Home        Leeds
# 7    Lost  8 wickets  England v West Indies      Home     The Oval
# 8     Won  4 wickets        England v India      Home        Leeds
# 9     Won  6 wickets        England v India      Home     The Oval
# 10   Lost  7 wickets     England v Pakistan      Home   Nottingham
# 11   Lost  8 wickets     England v Pakistan      Home   Birmingham
# 12    Won  3 wickets    Australia v England      Away    Melbourne
# ...

# %%
df = df [(df['Result'] =='Won') | (df['Result'] =='Lost')]

# %%
df.head(10)
# Out:
#    Result     Margin                  Match Home/Away      Ground  Match Date  \
# 0    Lost  5 wickets    Australia v England      Away   Melbourne  1971/01/05
# 1     Won  6 wickets    England v Australia      Home  Manchester  1972/08/24
# 2    Lost  5 wickets    England v Australia      Home      Lord's  1972/08/26
# 3     Won  2 wickets    England v Australia      Home  Birmingham  1972/08/28
# 4     Won  7 wickets  England v New Zealand      Home     Swansea  1973/07/18
# 6     Won  1 wickets  England v West Indies      Home       Leeds  1973/09/05
# 7    Lost  8 wickets  England v West Indies      Home    The Oval  1973/09/07
# 8     Won  4 wickets        England v India      Home       Leeds  1974/07/13
# 9     Won  6 wickets        England v India      Home    The Oval  1974/07/15
# 10   Lost  7 wickets     England v Pakistan      Home  Nottingham  1974/08/31
#
#    Match Month  Match Year Match Period  Matches  Country
# ...

# %%
df.columns
# Out:
# Index(['Result', 'Margin', 'Match', 'Home/Away', 'Ground', 'Match Date',
#        'Match Month', 'Match Year', 'Match Period', 'Matches', 'Country'],
#       dtype='object')

# %%
df_new
# Out:
#     Result Home/Away  Matches  Match_Australia v India  \
# 368   Lost      Home        1                     True
# 370    Won      Home        1                     True
# 371    Won      Home        1                     True
# 372    Won      Home        1                     True
# 374    Won      Home        1                     True
# ..     ...       ...      ...                      ...
# 911    Won      Away        1                    False
# 919   Lost      Home        1                     True
# 927    Won      Away        1                    False
# 928   Lost      Away        1                    False
# 929   Lost      Away        1                    False
#
#      Match_India v Australia
# 368                    False
# 370                    False
# 371                    False
# 372                    False
# 374                    False
# ..                       ...
# 911                     True
# 919                    False
# 927                     True
# ...

# %%
df_new = df[['Result', 'Match', 'Home/Away', 'Matches']]

# %%
df_new = df_new[(df_new['Match'] == 'Australia v India') | (df_new['Match'] == 'India v Australia')] 
df_new
# Out:
#      Result              Match Home/Away  Matches
# 368    Lost  Australia v India      Home        1
# 370     Won  Australia v India      Home        1
# 371     Won  Australia v India      Home        1
# 372     Won  Australia v India      Home        1
# 374     Won  Australia v India      Home        1
# ...     ...                ...       ...      ...
# 2745   Lost  India v Australia      Home        1
# 2747    Won  Australia v India      Away        1
# 2762   Lost  India v Australia      Home        1
# 2763    Won  India v Australia      Home        1
# 2764    Won  India v Australia      Home        1
#
# [260 rows x 4 columns]

# %%
df_new = df_new[((df_new['Match'] == 'Australia v India') & (df_new['Home/Away'] == 'Home'))  | ((df_new['Match'] == 'India v Australia') & (df_new['Home/Away'] == 'Away'))  ] 
df_new
# Out:
#     Result              Match Home/Away  Matches
# 368   Lost  Australia v India      Home        1
# 370    Won  Australia v India      Home        1
# 371    Won  Australia v India      Home        1
# 372    Won  Australia v India      Home        1
# 374    Won  Australia v India      Home        1
# ..     ...                ...       ...      ...
# 911    Won  India v Australia      Away        1
# 919   Lost  Australia v India      Home        1
# 927    Won  India v Australia      Away        1
# 928   Lost  India v Australia      Away        1
# 929   Lost  India v Australia      Away        1
#
# [130 rows x 4 columns]

# %%
df_new
# Out:
#     Result              Match Home/Away  Matches
# 368   Lost  Australia v India      Home        1
# 370    Won  Australia v India      Home        1
# 371    Won  Australia v India      Home        1
# 372    Won  Australia v India      Home        1
# 374    Won  Australia v India      Home        1
# ..     ...                ...       ...      ...
# 911    Won  India v Australia      Away        1
# 919   Lost  Australia v India      Home        1
# 927    Won  India v Australia      Away        1
# 928   Lost  India v Australia      Away        1
# 929   Lost  India v Australia      Away        1
#
# [130 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_new['Match'] = le.fit_transform(df_new['Match'])
# Out:
# C:\Users\dbda.STUDENTSDC\AppData\Local\Temp\ipykernel_17528\611256519.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['Match'] = le.fit_transform(df_new['Match'])  # Encodes Gender as 0 -Female and 1 - Male

# %%
df_new
# Out:
#     Result  Match Home/Away  Matches
# 368   Lost      0      Home        1
# 370    Won      0      Home        1
# 371    Won      0      Home        1
# 372    Won      0      Home        1
# 374    Won      0      Home        1
# ..     ...    ...       ...      ...
# 911    Won      1      Away        1
# 919   Lost      0      Home        1
# 927    Won      1      Away        1
# 928   Lost      1      Away        1
# 929   Lost      1      Away        1
#
# [130 rows x 4 columns]

# %%
le = LabelEncoder()
df_new['Home/Away'] = le.fit_transform(df_new['Home/Away'])
df_new
# Out:
# C:\Users\dbda.STUDENTSDC\AppData\Local\Temp\ipykernel_17528\833915781.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['Home/Away'] = le.fit_transform(df_new['Home/Away'])
#     Result  Match  Home/Away  Matches
# 368   Lost      0          1        1
# 370    Won      0          1        1
# 371    Won      0          1        1
# 372    Won      0          1        1
# 374    Won      0          1        1
# ..     ...    ...        ...      ...
# 911    Won      1          0        1
# 919   Lost      0          1        1
# 927    Won      1          0        1
# 928   Lost      1          0        1
# 929   Lost      1          0        1
#
# [130 rows x 4 columns]
